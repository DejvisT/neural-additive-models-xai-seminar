# %% [markdown]
# ## Training the Neural Additive Model (NAM) for correlated nonlinear synthetic data

# %%
import json
import sys
from pathlib import Path

# Add src to path for imports
project_root = Path.cwd().parent.parent
src_path = project_root / 'src'
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

# Get paths relative to project root
results_dir = project_root / 'results'
config_dir = project_root / 'config'

# Load best hyperparameters
best_hp_json = results_dir / 'hyperparameter_tuning' / 'nam' / 'hp_tuning_correlated_nonlinear' / 'best_hp.json'
with open(best_hp_json, 'r') as f:
    best_hp = json.load(f)

# Load fixed training parameters from JSON
fixed_json = config_dir / 'training' / 'nam_training_parameters_correlated_nonlinear.json'
with open(fixed_json, 'r') as f:
    fixed = json.load(f)

print(f"Loaded fixed training params from: {fixed_json}")
# Out:
# Loaded fixed training params from: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\config\training\nam_training_parameters_correlated_nonlinear.json

# %%
rhos = [0, 0.3, 0.6, 0.8, 0.9, 0.95]
seeds = list(range(20))  # 20 dataset seeds per rho

# Set training output directory
project_root = Path.cwd().parent.parent
base_logdir = project_root / 'results' / 'training' / 'nam' / 'correlated_nonlinear'
base_logdir.mkdir(parents=True, exist_ok=True)

skip_if_checkpoint_exists = True
per_run_timeout_s = 3600
# Out:
# The history saving thread hit an unexpected error (OperationalError('database or disk is full')).History will not be written to the database.

# %%
from utils import run_nam_train_sweep

runs, summary_path = run_nam_train_sweep(
    rhos=rhos,
    seeds=seeds,
    fixed=fixed,
    best_hp=best_hp,
    base_logdir=base_logdir,
    skip_if_checkpoint_exists=skip_if_checkpoint_exists,
    per_run_timeout_s=per_run_timeout_s,
)

# %%
import neural_additive_models.data_utils as data_utils
from utils import load_col_min_max, inverse_min_max_scaler

dataset_name = 'Correlated_nonlinear'
correlated_n = 20000
rho = 0
seed = 0
is_regression = True
data =  data_utils.load_dataset(dataset_name, correlated_n, rho, seed)
data_x, data_y, column_names = data
col_min_max = load_col_min_max(dataset_name, correlated_n, rho, seed)
# Out:
# WARNING:tensorflow:From c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\.venv\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
from utils import get_hyperparameter_tuning_indices

fold_train_indices, fold_test_indices = get_hyperparameter_tuning_indices(
    data_x,
    data_y,
    test_size=0.2,
    val_size=0.2,
    is_regression=True,
    random_state=42,  # Must match hp_random_state from training
    combine_train_val=True,  # ← Set to True if combine_train_val_for_final_training=true
)

# %%
from utils import prepare_feature_arrays, get_dataset_config

# Step 1: Prepare data
SINGLE_FEATURES_ORIGINAL, UNIQUE_FEATURES_ORIGINAL, UNIQUE_FEATURES = prepare_feature_arrays(
    data_x, column_names, col_min_max, inverse_min_max_scaler
)

# Step 2: Load dataset-specific config
COL_NAMES, FEATURE_LABEL_MAPPING, CATEGORICAL_NAMES = get_dataset_config(dataset_name, column_names)

# %%
from utils import analyze_correlated_shape_functions, plot_nam_contributions_with_density

dataset_name = "Correlated_nonlinear"
rho = 0
seeds = list(range(20))

(
    seed_rmses,
    all_hist_data,
    all_mean_pred,
    UNIQUE_FEATURES_ORIGINAL,
    SINGLE_FEATURES_ORIGINAL,
    column_names,
) = analyze_correlated_shape_functions(
    dataset_name=dataset_name,
    rho=rho,
    seeds=seeds,
    fixed=fixed,
    best_hp=best_hp,
    fold_num_trained=1,
    n_folds=2,
    split_num_trained=1,
    random_state=42,
    n_grid=400,
    ckpt_base_dir=str(base_logdir),
    print_every=5,
)

col_mapping = {c: c for c in column_names}
feature_mapping = {}
categorical_names = []

fig = plot_nam_contributions_with_density(
    hist_data=all_hist_data,
    unique_features=UNIQUE_FEATURES_ORIGINAL,
    single_features=SINGLE_FEATURES_ORIGINAL,
    categorical_names=categorical_names,
    col_mapping=col_mapping,
    feature_mapping=feature_mapping,
    mean_pred=all_mean_pred,
    feature_to_use=column_names,
    dataset_label=f"{dataset_name} shape functions (rho={rho})",
)
# Out:
# Processing seed 0...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1950
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1950
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1300
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1300
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# ✅ Restored NAM from checkpoint.
# Processing seed 5...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_6/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_6/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_7/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_7/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_8/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_8/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_9/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1170
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_9/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1170
# ✅ Restored NAM from checkpoint.
# Processing seed 10...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_10/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_10/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_11/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_11/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# ✅ Restored NAM from checkpoint.
# Processing seed 15...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1300
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1300
# ✅ Restored NAM from checkpoint.
#
# RMSE over seeds (rho=0, train/val/test, fold_num=1): 0.5894 ± 0.0208

# %%
from utils import evaluate_correlated_models

(rmse_by_rho_seed, rmse_df, summary, rho_rmses), (shape_df, shape_by_rho_seed_feature) = evaluate_correlated_models(
    dataset_name="Correlated_nonlinear",
    rhos=rhos,
    seeds=seeds,
    fixed=fixed,
    best_hp=best_hp,
    compute_shape_rmse=True,
    ckpt_base_dir=str(base_logdir)
)
# Out:
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1950
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1950
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1300
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1300
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_6/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_6/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_7/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_7/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_8/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_8/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_9/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1170
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_9/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1170
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_10/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_10/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_11/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_11/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1300
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_0/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1300
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1040
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1040
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3120
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3120
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1950
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1950
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_6/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_6/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_7/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1950
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_7/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1950
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_8/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_8/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_9/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_9/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_10/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1300
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_10/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1300
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_11/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_11/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2990
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2990
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1300
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1300
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1950
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1950
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_03/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_6/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_6/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_7/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_7/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_8/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_8/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_9/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2600
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_9/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2600
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_10/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_10/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_11/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_11/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3510
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3510
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2990
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2990
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_06/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_6/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_6/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_7/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1950
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_7/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1950
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_8/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_8/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_9/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_9/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_10/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_10/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_11/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_11/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1170
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1170
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_08/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# ✅ Restored NAM from checkpoint.
# ...
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_11/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1040
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1040
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1040
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1040
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3510
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3510
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3510
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3510
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2730
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_09/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_0/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1430
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_1/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3770
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_2/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3770
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_3/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_4/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_5/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_6/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_6/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1820
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_7/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_7/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_8/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_8/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_9/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_9/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2470
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_10/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_10/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1560
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_11/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_11/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_12/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2080
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3120
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_13/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3120
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_14/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_15/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2860
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3510
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_16/fold_1/split_1/model_0/best_checkpoint\model.ckpt-3510
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_17/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2210
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_18/fold_1/split_1/model_0/best_checkpoint\model.ckpt-2340
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# Feature widths: [128, 128, 128, 128, 128, 128, 128, 128, 128, 128]
# Num input features: 10
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\correlated_nonlinear/rho_095/seed_19/fold_1/split_1/model_0/best_checkpoint\model.ckpt-1690
# ✅ Restored NAM from checkpoint.

# %%
# Display and save test RMSE summary (mean and std per rho)
import json

print("="*70)
print("TEST RMSE SUMMARY BY RHO (Correlated Nonlinear)")
print("="*70)
print(summary.to_string(index=False))
print("="*70)

# Save to JSON
results_dir = project_root / 'results' / 'evaluation'
results_dir.mkdir(parents=True, exist_ok=True)

summary_json = results_dir / 'correlated_nonlinear_rmse_summary.json'
with open(summary_json, 'w') as f:
    json.dump({
        'dataset': 'Correlated_nonlinear',
        'summary': summary.to_dict('records')
    }, f, indent=2)

rmse_df_json = results_dir / 'correlated_nonlinear_rmse_full.json'
with open(rmse_df_json, 'w') as f:
    json.dump({
        'dataset': 'Correlated_nonlinear',
        'rmse_by_rho_seed': rmse_df.to_dict('records')
    }, f, indent=2)

print(f"\nSaved summary to: {summary_json}")
print(f"Saved full RMSE data to: {rmse_df_json}")
# Out:
# ======================================================================
# TEST RMSE SUMMARY BY RHO (Correlated Nonlinear)
# ======================================================================
#  rho     mean      std  count
# 0.00 0.589356 0.021345     20
# 0.30 0.594467 0.020274     20
# 0.60 0.600476 0.022630     20
# 0.80 0.597097 0.030500     20
# 0.90 0.606848 0.019492     20
# 0.95 0.616174 0.026788     20
# ======================================================================
#
# Saved summary to: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\evaluation\correlated_nonlinear_rmse_summary.json
# Saved full RMSE data to: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\evaluation\correlated_nonlinear_rmse_full.json

# %%
from utils import plot_rmse_boxplot_vs_rho

plot_rmse_boxplot_vs_rho(rmse_df, dataset_label="Nonlinear")

# %%
from utils import analyze_shape_rmse

analyze_shape_rmse(shape_df, dataset_label="Nonlinear")
# Out:
# Shape RMSE Statistics:
#    Overall mean: 2.3068
#    Overall std: 3.9926
#    Min: 0.0059
#    Max: 16.6857
#
# Per-feature average shape RMSE (mean ± std):
#    X9: 0.0454 ± 0.0281
#    X7: 0.0488 ± 0.0365
#    X5: 0.0504 ± 0.0279
#    X10: 0.0509 ± 0.0310
#    X8: 0.0555 ± 0.0343
#    X6: 0.0559 ± 0.0349
#    X3: 1.1633 ± 0.3186
#    X1: 1.7752 ± 0.1395
#    X2: 7.9538 ± 1.0839
#    X4: 11.8691 ± 1.6002
