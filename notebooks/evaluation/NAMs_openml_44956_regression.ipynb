# %% [markdown]
# ## Evaluation of the Neural Additive Model (NAM) on OpenML Dataset
#
# This notebook evaluates trained NAM models on OpenML datasets.

# %%
# ============================================================================
# CONFIGURATION
# ============================================================================
OPENML_DATASET_ID = 44956  # OpenML dataset ID
TASK_TYPE = "regression"  # Options: "classification" or "regression"
NUM_FOLDS = 5  # Number of folds for cross-validation
NUM_SPLITS = 20  # Number of splits per fold

# %%
import sys
from pathlib import Path

# Add src to path for imports
project_root = Path.cwd().parent.parent
src_path = project_root / 'src'
if str(src_path) not in sys.path:
    sys.path.insert(0, str(src_path))

import neural_additive_models.data_utils as data_utils
import numpy as np
from utils import inverse_min_max_scaler
# Out:
# WARNING:tensorflow:From c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\.venv\lib\site-packages\tensorflow\python\compat\v2_compat.py:107: disable_resource_variables (from tensorflow.python.ops.variable_scope) is deprecated and will be removed in a future version.
# Instructions for updating:
# non-resource variables are not supported in the long term

# %%
# Load dataset
dataset_name = f"OpenML_{OPENML_DATASET_ID}_{TASK_TYPE}"
is_regression = (TASK_TYPE == "regression")

print(f"Loading dataset: {dataset_name}")
data = data_utils.load_dataset(dataset_name)
data_x, data_y, column_names = data

print(f"Dataset shape: {data_x.shape}")
print(f"Target shape: {data_y.shape}")
print(f"Number of features: {data_x.shape[1]}")
print(f"Task type: {'Regression' if is_regression else 'Classification'}")

col_min_max = {}
for i, col_name in enumerate(column_names):
    col_data = data_x[:, i]
    col_min_max[col_name] = (float(np.min(col_data)), float(np.max(col_data)))
# Out:
# Loading dataset: OpenML_44956_regression
# Dataset shape: (4177, 10)
# Target shape: (4177,)
# Number of features: 10
# Task type: Regression

# %%
from utils import create_fold_indices

fold_train_indices, fold_test_indices = create_fold_indices(
    data_x,
    data_y,
    num_folds=NUM_FOLDS,
    is_regression=is_regression,
    random_state=42
)

# %%
from utils import prepare_feature_arrays, get_dataset_config

# Step 1: Prepare data
SINGLE_FEATURES_ORIGINAL, UNIQUE_FEATURES_ORIGINAL, UNIQUE_FEATURES = prepare_feature_arrays(
    data_x, column_names, col_min_max, inverse_min_max_scaler
)

# Step 2: Use default config
COL_NAMES = {dataset_name: {name: name for name in column_names}}
FEATURE_LABEL_MAPPING = {dataset_name: {name: name for name in column_names}}
CATEGORICAL_NAMES = []

# %%
from utils import gather_nam_predictions_and_hist_data

# Set results directory
project_root = Path.cwd().parent.parent
base_logdir = project_root / 'results' / 'training' / 'nam' / f'openml_{OPENML_DATASET_ID}_{TASK_TYPE}'

all_preds_per_fold, all_hist_data, all_mean_pred = gather_nam_predictions_and_hist_data(
    fold_test_indices=fold_test_indices,
    data_x=data_x,
    column_names=column_names,
    unique_features=UNIQUE_FEATURES,
    dataset_name=dataset_name,
    base_logdir=str(base_logdir),
    num_folds=NUM_FOLDS,
    num_splits=NUM_SPLITS,
    print_every=5
)
# Out:
# Processing fold 1 (test set size: 836)...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_1/model_0/best_checkpoint\model.ckpt-540
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_1/model_0/best_checkpoint\model.ckpt-540
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_2/model_0/best_checkpoint\model.ckpt-540
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_2/model_0/best_checkpoint\model.ckpt-540
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_3/model_0/best_checkpoint\model.ckpt-180
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_3/model_0/best_checkpoint\model.ckpt-180
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_4/model_0/best_checkpoint\model.ckpt-820
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_4/model_0/best_checkpoint\model.ckpt-820
# ✅ Restored NAM from checkpoint.
#   Processing split 5...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_5/model_0/best_checkpoint\model.ckpt-300
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_5/model_0/best_checkpoint\model.ckpt-300
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_6/model_0/best_checkpoint\model.ckpt-380
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_6/model_0/best_checkpoint\model.ckpt-380
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_7/model_0/best_checkpoint\model.ckpt-280
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_7/model_0/best_checkpoint\model.ckpt-280
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_8/model_0/best_checkpoint\model.ckpt-560
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_8/model_0/best_checkpoint\model.ckpt-560
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_9/model_0/best_checkpoint\model.ckpt-720
# Feature widths: [4, 4, 4, 128, 128, 98, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_9/model_0/best_checkpoint\model.ckpt-720
# ✅ Restored NAM from checkpoint.
#   Processing split 10...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_10/model_0/best_checkpoint\model.ckpt-260
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_10/model_0/best_checkpoint\model.ckpt-260
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_11/model_0/best_checkpoint\model.ckpt-360
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_11/model_0/best_checkpoint\model.ckpt-360
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_12/model_0/best_checkpoint\model.ckpt-540
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_12/model_0/best_checkpoint\model.ckpt-540
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_13/model_0/best_checkpoint\model.ckpt-620
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_13/model_0/best_checkpoint\model.ckpt-620
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_14/model_0/best_checkpoint\model.ckpt-380
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_14/model_0/best_checkpoint\model.ckpt-380
# ✅ Restored NAM from checkpoint.
#   Processing split 15...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_15/model_0/best_checkpoint\model.ckpt-300
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_15/model_0/best_checkpoint\model.ckpt-300
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_16/model_0/best_checkpoint\model.ckpt-180
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_16/model_0/best_checkpoint\model.ckpt-180
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_17/model_0/best_checkpoint\model.ckpt-540
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_17/model_0/best_checkpoint\model.ckpt-540
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_18/model_0/best_checkpoint\model.ckpt-400
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_18/model_0/best_checkpoint\model.ckpt-400
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_19/model_0/best_checkpoint\model.ckpt-260
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_19/model_0/best_checkpoint\model.ckpt-260
# ✅ Restored NAM from checkpoint.
#   Processing split 20...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_20/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_1/split_20/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Processing fold 2 (test set size: 836)...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_1/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_1/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_2/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_2/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_3/model_0/best_checkpoint\model.ckpt-280
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_3/model_0/best_checkpoint\model.ckpt-280
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_4/model_0/best_checkpoint\model.ckpt-900
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_4/model_0/best_checkpoint\model.ckpt-900
# ✅ Restored NAM from checkpoint.
#   Processing split 5...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_5/model_0/best_checkpoint\model.ckpt-500
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_5/model_0/best_checkpoint\model.ckpt-500
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_6/model_0/best_checkpoint\model.ckpt-380
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_6/model_0/best_checkpoint\model.ckpt-380
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_7/model_0/best_checkpoint\model.ckpt-400
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_7/model_0/best_checkpoint\model.ckpt-400
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_8/model_0/best_checkpoint\model.ckpt-300
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_8/model_0/best_checkpoint\model.ckpt-300
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_9/model_0/best_checkpoint\model.ckpt-1020
# Feature widths: [4, 4, 4, 128, 128, 98, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_9/model_0/best_checkpoint\model.ckpt-1020
# ✅ Restored NAM from checkpoint.
#   Processing split 10...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_10/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_10/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_11/model_0/best_checkpoint\model.ckpt-180
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_11/model_0/best_checkpoint\model.ckpt-180
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_12/model_0/best_checkpoint\model.ckpt-260
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_12/model_0/best_checkpoint\model.ckpt-260
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_13/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_13/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_14/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_14/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
#   Processing split 15...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_15/model_0/best_checkpoint\model.ckpt-360
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_15/model_0/best_checkpoint\model.ckpt-360
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_16/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_16/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_17/model_0/best_checkpoint\model.ckpt-140
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_17/model_0/best_checkpoint\model.ckpt-140
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_18/model_0/best_checkpoint\model.ckpt-260
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_18/model_0/best_checkpoint\model.ckpt-260
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_19/model_0/best_checkpoint\model.ckpt-120
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_19/model_0/best_checkpoint\model.ckpt-120
# ✅ Restored NAM from checkpoint.
#   Processing split 20...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_20/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_2/split_20/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Processing fold 3 (test set size: 835)...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_1/model_0/best_checkpoint\model.ckpt-300
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_1/model_0/best_checkpoint\model.ckpt-300
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_2/model_0/best_checkpoint\model.ckpt-1220
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_2/model_0/best_checkpoint\model.ckpt-1220
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_3/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_3/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_4/model_0/best_checkpoint\model.ckpt-800
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_4/model_0/best_checkpoint\model.ckpt-800
# ✅ Restored NAM from checkpoint.
#   Processing split 5...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_5/model_0/best_checkpoint\model.ckpt-300
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_5/model_0/best_checkpoint\model.ckpt-300
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_6/model_0/best_checkpoint\model.ckpt-540
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_6/model_0/best_checkpoint\model.ckpt-540
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_7/model_0/best_checkpoint\model.ckpt-500
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_7/model_0/best_checkpoint\model.ckpt-500
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_8/model_0/best_checkpoint\model.ckpt-360
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_8/model_0/best_checkpoint\model.ckpt-360
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_9/model_0/best_checkpoint\model.ckpt-600
# Feature widths: [4, 4, 4, 128, 128, 98, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_9/model_0/best_checkpoint\model.ckpt-600
# ✅ Restored NAM from checkpoint.
#   Processing split 10...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_10/model_0/best_checkpoint\model.ckpt-280
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_10/model_0/best_checkpoint\model.ckpt-280
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_11/model_0/best_checkpoint\model.ckpt-360
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_11/model_0/best_checkpoint\model.ckpt-360
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_12/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_12/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_13/model_0/best_checkpoint\model.ckpt-620
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_13/model_0/best_checkpoint\model.ckpt-620
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_14/model_0/best_checkpoint\model.ckpt-280
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_14/model_0/best_checkpoint\model.ckpt-280
# ✅ Restored NAM from checkpoint.
#   Processing split 15...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_15/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_15/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_16/model_0/best_checkpoint\model.ckpt-240
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_16/model_0/best_checkpoint\model.ckpt-240
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_17/model_0/best_checkpoint\model.ckpt-140
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_17/model_0/best_checkpoint\model.ckpt-140
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_18/model_0/best_checkpoint\model.ckpt-360
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_18/model_0/best_checkpoint\model.ckpt-360
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_19/model_0/best_checkpoint\model.ckpt-200
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_19/model_0/best_checkpoint\model.ckpt-200
# ✅ Restored NAM from checkpoint.
#   Processing split 20...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_20/model_0/best_checkpoint\model.ckpt-260
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_3/split_20/model_0/best_checkpoint\model.ckpt-260
# ✅ Restored NAM from checkpoint.
# Processing fold 4 (test set size: 835)...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_1/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_1/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_2/model_0/best_checkpoint\model.ckpt-540
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_2/model_0/best_checkpoint\model.ckpt-540
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_3/model_0/best_checkpoint\model.ckpt-360
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_3/model_0/best_checkpoint\model.ckpt-360
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_4/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_4/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
#   Processing split 5...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_5/model_0/best_checkpoint\model.ckpt-620
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_5/model_0/best_checkpoint\model.ckpt-620
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_6/model_0/best_checkpoint\model.ckpt-780
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_6/model_0/best_checkpoint\model.ckpt-780
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_7/model_0/best_checkpoint\model.ckpt-280
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_7/model_0/best_checkpoint\model.ckpt-280
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_8/model_0/best_checkpoint\model.ckpt-440
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_8/model_0/best_checkpoint\model.ckpt-440
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_9/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 98, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_9/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
#   Processing split 10...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_10/model_0/best_checkpoint\model.ckpt-280
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_10/model_0/best_checkpoint\model.ckpt-280
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_11/model_0/best_checkpoint\model.ckpt-780
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_11/model_0/best_checkpoint\model.ckpt-780
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_12/model_0/best_checkpoint\model.ckpt-240
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_12/model_0/best_checkpoint\model.ckpt-240
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_13/model_0/best_checkpoint\model.ckpt-920
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_13/model_0/best_checkpoint\model.ckpt-920
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_14/model_0/best_checkpoint\model.ckpt-280
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_14/model_0/best_checkpoint\model.ckpt-280
# ✅ Restored NAM from checkpoint.
#   Processing split 15...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_15/model_0/best_checkpoint\model.ckpt-360
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_15/model_0/best_checkpoint\model.ckpt-360
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_16/model_0/best_checkpoint\model.ckpt-200
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_16/model_0/best_checkpoint\model.ckpt-200
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_17/model_0/best_checkpoint\model.ckpt-360
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_17/model_0/best_checkpoint\model.ckpt-360
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_18/model_0/best_checkpoint\model.ckpt-340
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_18/model_0/best_checkpoint\model.ckpt-340
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_19/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_19/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
#   Processing split 20...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_20/model_0/best_checkpoint\model.ckpt-280
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_4/split_20/model_0/best_checkpoint\model.ckpt-280
# ✅ Restored NAM from checkpoint.
# Processing fold 5 (test set size: 835)...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_1/model_0/best_checkpoint\model.ckpt-120
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_1/model_0/best_checkpoint\model.ckpt-120
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_2/model_0/best_checkpoint\model.ckpt-580
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_2/model_0/best_checkpoint\model.ckpt-580
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_3/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_3/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_4/model_0/best_checkpoint\model.ckpt-1060
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_4/model_0/best_checkpoint\model.ckpt-1060
# ✅ Restored NAM from checkpoint.
#   Processing split 5...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_5/model_0/best_checkpoint\model.ckpt-320
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_5/model_0/best_checkpoint\model.ckpt-320
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_6/model_0/best_checkpoint\model.ckpt-620
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_6/model_0/best_checkpoint\model.ckpt-620
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_7/model_0/best_checkpoint\model.ckpt-300
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_7/model_0/best_checkpoint\model.ckpt-300
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_8/model_0/best_checkpoint\model.ckpt-300
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_8/model_0/best_checkpoint\model.ckpt-300
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_9/model_0/best_checkpoint\model.ckpt-360
# Feature widths: [4, 4, 4, 128, 128, 98, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_9/model_0/best_checkpoint\model.ckpt-360
# ✅ Restored NAM from checkpoint.
#   Processing split 10...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_10/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_10/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_11/model_0/best_checkpoint\model.ckpt-280
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_11/model_0/best_checkpoint\model.ckpt-280
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_12/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_12/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_13/model_0/best_checkpoint\model.ckpt-780
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_13/model_0/best_checkpoint\model.ckpt-780
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_14/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_14/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
#   Processing split 15...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_15/model_0/best_checkpoint\model.ckpt-260
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_15/model_0/best_checkpoint\model.ckpt-260
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_16/model_0/best_checkpoint\model.ckpt-140
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_16/model_0/best_checkpoint\model.ckpt-140
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_17/model_0/best_checkpoint\model.ckpt-120
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_17/model_0/best_checkpoint\model.ckpt-120
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_18/model_0/best_checkpoint\model.ckpt-340
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_18/model_0/best_checkpoint\model.ckpt-340
# ✅ Restored NAM from checkpoint.
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_19/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 102, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_19/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.
#   Processing split 20...
# Using checkpoint: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_20/model_0/best_checkpoint\model.ckpt-420
# Feature widths: [4, 4, 4, 128, 128, 100, 128, 128, 128, 128]
# Num input features: 10
# Auto-detected shallow=False from checkpoint structure
# INFO:tensorflow:Restoring parameters from c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\training\nam\openml_44956_regression/fold_5/split_20/model_0/best_checkpoint\model.ckpt-420
# ✅ Restored NAM from checkpoint.

# %%
from utils import plot_nam_contributions_with_density

fig = plot_nam_contributions_with_density(
    hist_data=all_hist_data,
    unique_features=UNIQUE_FEATURES_ORIGINAL,
    single_features=SINGLE_FEATURES_ORIGINAL,
    categorical_names=CATEGORICAL_NAMES,
    col_mapping=COL_NAMES[dataset_name],
    feature_mapping=FEATURE_LABEL_MAPPING[dataset_name],
    mean_pred=all_mean_pred,
    feature_to_use=column_names,
    y_limits=(-0.1, 0.1)
)

# %%
from utils import plot_feature_importance_across_splits

sorted_features, sorted_mean, sorted_std = plot_feature_importance_across_splits(
    all_hist_data,
    all_mean_pred,
    dataset_name
)

# %%
from utils import evaluate_ensemble_across_folds

fold_rmses, avg_rmse, std_rmse = evaluate_ensemble_across_folds(
    all_preds_per_fold,
    fold_test_indices,
    data_y,
    is_regression=True,
    verbose=True
)
# Out:
# Fold 1 RMSE (test set only): 2.3146 (n=836)
# Fold 2 RMSE (test set only): 2.1042 (n=836)
# Fold 3 RMSE (test set only): 2.4041 (n=835)
# Fold 4 RMSE (test set only): 2.3573 (n=835)
# Fold 5 RMSE (test set only): 2.0648 (n=835)
#
# Average Ensemble RMSE across folds (test sets only): 2.2490
# Std of Ensemble RMSE across folds: 0.1378

# %%
from utils import save_performance_metrics

# Save detailed performance metrics for statistical analysis
output_file = save_performance_metrics(
    all_preds_per_fold=all_preds_per_fold,
    fold_test_indices=fold_test_indices,
    data_y=data_y,
    dataset_id=OPENML_DATASET_ID,
    dataset_name=dataset_name,
    task_type=TASK_TYPE,
    model_type='NAM',
    num_folds=NUM_FOLDS,
    num_splits=NUM_SPLITS,
    is_regression=is_regression,
    project_root=project_root,
    verbose=True
)
# Out:
# ======================================================================
# PERFORMANCE METRICS SAVED
# ======================================================================
# Saved to: c:\Users\dejvi\Documents\pythonProject\neural-additive-models-xai-seminar-1\results\evaluation\nam_OpenML_44956_regression_performance.json
# Summary:
#   Mean RMSE: 2.2490
#   Std RMSE: 0.1378
#   Min RMSE: 2.0648
#   Max RMSE: 2.4041
# ======================================================================
